# %% [markdown]
# <a href="https://colab.research.google.com/github/lisabecker/nlp-fundamentals/blob/main/0203_who_wrote_it.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 2 Use Case - Who wrote it? Authorship Attribution with heuristic NLP
#
# In this exercise, we'll get familiar with heuristic authorship attribution, a method that combines linguistic analysis with data science to identify the author of a given text. This approach goes beyond the content, focusing on unique stylistic and linguistic patterns that characterize an author's writing. By analyzing features like word choice, sentence structure, and stylistic elements, we can employ computational techniques to make educated guesses about the authorship of unknown or disputed texts.
#
# For this task, we'll use Jane Austen's [Pride and Prejudice](https://www.gutenberg.org/files/1342/1342-0.txt) and William Blake's [Songs of Innocence and of Experience](https://www.gutenberg.org/cache/epub/1934/pg1934.txt) to extract the author's style and apply it to a new text. Both works are publicly available on [Project Gutenberg](https://www.gutenberg.org/).
#
# ## 1. Setting up the environment

# %%
# !pip install --q requests beautifulsoup4 nltk

# %% [markdown]
# ## 2. Downloading and Preparing Texts
#
# In this section, we download classic texts from Project Gutenberg using the `requests` library and parse the HTML content with `BeautifulSoup` to extract the text. We specifically target the main content of the books by locating the start and end markers of the Project Gutenberg texts. This approach ensures that we only work with the actual content of the books, excluding headers and footers added by Project Gutenberg.

# %%
# URLs of the books from Project Gutenberg
pride_and_prejudice_url = 'https://www.gutenberg.org/files/1342/1342-0.txt'  # Pride and Prejudice
songs_of_innocence_url = 'https://www.gutenberg.org/cache/epub/1934/pg1934.txt' # Songs of Innocence and of Experience

# %%
import requests
from bs4 import BeautifulSoup

def download_book(url):
    """Download the text of a book from Project Gutenberg."""
    response = requests.get(url, timeout=120)
    response.raise_for_status()  # Raise an error for bad status codes

    soup = BeautifulSoup(response.content, 'html.parser')
    text = soup.get_text()
    start_marker = '*** START OF THE PROJECT GUTENBERG EBOOK'
    end_marker = '*** END OF THE PROJECT GUTENBERG EBOOK'

    # Find the indices of the start and end markers
    start = text.find(start_marker)
    end = text.find(end_marker)

    if start != -1 and end != -1:
      # Adjust the start index to not include the start marker itself
      start += len(start_marker)
      # Slice the text to get the content between the markers
    return text[start:end].strip()

# %%
# Download the books
pride_and_prejudice_text = download_book(pride_and_prejudice_url)
start = pride_and_prejudice_text.find("It is a truth universally acknowledged")
pride_and_prejudice_text = pride_and_prejudice_text[start:]

songs_of_innocence_text = download_book(songs_of_innocence_url)
start = songs_of_innocence_text.find("Piping down the valleys wild")
songs_of_innocence_text = songs_of_innocence_text[start:]

print("Books loaded into memory.")
# Out:
# Books loaded into memory.

# %%
pride_and_prejudice_sample = pride_and_prejudice_text[:116]
songs_of_innocence_sample = songs_of_innocence_text[:151]

print(f"=== Start of Pride and Prejudice ===\n'{pride_and_prejudice_sample}'")
print(f"\n=== Start of Songs of Innocence and of Experience ===\n'{songs_of_innocence_sample}'")
# Out:
# === Start of Pride and Prejudice ===
# 'It is a truth universally acknowledged, that a single man in possession
# of a good fortune must be in want of a wife'
#
# === Start of Songs of Innocence and of Experience ===
# 'Piping down the valleys wild,
#     Piping songs of pleasant glee,
# On a cloud I saw a child,
#     And he laughing said to me:
#
# ‘Pipe a song about a L'

# %% [markdown]
# ## 3. Text Processing and Tokenization
#
# Here, we conduct initial text processing tasks essential for authorship attribution analysis with the Regular Expressions (RegEx) and Natural Language Toolkit (NLTK).
#
# We demonstrate the text preprocessing steps on a sample from "Songs of Innocence and of Experience," including:
# - Converting all letters to lowercase.
# - Removing punctuation.
# - Splitting the text into tokens (words).
# - Removing stopwords (common words that usually don't carry much meaning).
#
# Furthermore, we define functions `clean_text` and `remove_stopwords` to standardize and streamline these preprocessing steps. We then apply these functions to the entire texts of "Pride and Prejudice" and "Songs of Innocence and of Experience" to prepare them for the next steps in our analysis.

# %%
import re
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print("=== All letters set to lowercase ===")
songs_of_innocence_sample.lower()
# Out:
# === All letters set to lowercase ===
# 'piping down the valleys wild,\r\n    piping songs of pleasant glee,\r\non a cloud i saw a child,\r\n    and he laughing said to me:\r\n\r\n‘pipe a song about a l'

# %%
print("=== Punctuation removed ===")
re.sub(r'[^a-zA-Z\s]', '', songs_of_innocence_sample)
# Out:
# === Punctuation removed ===
# 'Piping down the valleys wild\r\n    Piping songs of pleasant glee\r\nOn a cloud I saw a child\r\n    And he laughing said to me\r\n\r\nPipe a song about a L'

# %%
print("=== Text split into tokens ===")
tokens = word_tokenize(songs_of_innocence_sample)
print(tokens)
# Out:
# === Text split into tokens ===
# ['Piping', 'down', 'the', 'valleys', 'wild', ',', 'Piping', 'songs', 'of', 'pleasant', 'glee', ',', 'On', 'a', 'cloud', 'I', 'saw', 'a', 'child', ',', 'And', 'he', 'laughing', 'said', 'to', 'me', ':', '‘', 'Pipe', 'a', 'song', 'about', 'a', 'L']

# %%
print("=== Stopwords removed ===")
stop_words = set(stopwords.words('english'))
print([token for token in tokens if token not in stop_words])
# Out:
# === Stopwords removed ===
# ['Piping', 'valleys', 'wild', ',', 'Piping', 'songs', 'pleasant', 'glee', ',', 'On', 'cloud', 'I', 'saw', 'child', ',', 'And', 'laughing', 'said', ':', '‘', 'Pipe', 'song', 'L']

# %%
# Wrap lowercasing and punctuation removal from text into a function
def clean_text(text):
    text = text.lower() # Convert to lowercase
    text = re.sub(r'[^a-zA-Z\s]', '', text) # Remove punctuation
    return text

pride_and_prejudice_cleaned = clean_text(pride_and_prejudice_text)
songs_of_innocence_cleaned = clean_text(songs_of_innocence_text)

pride_and_prejudice_tokens = word_tokenize(pride_and_prejudice_cleaned)
songs_of_innocence_tokens = word_tokenize(songs_of_innocence_cleaned)

print("=== Pride and Prejudice - First 100 tokens ===\n", pride_and_prejudice_tokens[:100])
print("\n=== Songs of Innocence and of Expectations - First 100 tokens ===\n", songs_of_innocence_tokens[:100])
# Out:
# === Pride and Prejudice - First 100 tokens ===
#  ['it', 'is', 'a', 'truth', 'universally', 'acknowledged', 'that', 'a', 'single', 'man', 'in', 'possession', 'of', 'a', 'good', 'fortune', 'must', 'be', 'in', 'want', 'of', 'a', 'wife', 'however', 'little', 'known', 'the', 'feelings', 'or', 'views', 'of', 'such', 'a', 'man', 'may', 'be', 'on', 'his', 'first', 'entering', 'a', 'neighbourhood', 'this', 'truth', 'is', 'so', 'well', 'fixed', 'in', 'the', 'minds', 'of', 'the', 'surrounding', 'families', 'that', 'he', 'is', 'considered', 'as', 'the', 'rightful', 'property', 'of', 'some', 'one', 'or', 'other', 'of', 'their', 'daughters', 'my', 'dear', 'mr', 'bennet', 'said', 'his', 'lady', 'to', 'him', 'one', 'day', 'have', 'you', 'heard', 'that', 'netherfield', 'park', 'is', 'let', 'at', 'last', 'mr', 'bennet', 'replied', 'that', 'he', 'had', 'not', 'but']
#
# === Songs of Innocence and of Expectations - First 100 tokens ===
#  ['piping', 'down', 'the', 'valleys', 'wild', 'piping', 'songs', 'of', 'pleasant', 'glee', 'on', 'a', 'cloud', 'i', 'saw', 'a', 'child', 'and', 'he', 'laughing', 'said', 'to', 'me', 'pipe', 'a', 'song', 'about', 'a', 'lamb', 'so', 'i', 'piped', 'with', 'merry', 'cheer', 'piper', 'pipe', 'that', 'song', 'again', 'so', 'i', 'piped', 'he', 'wept', 'to', 'hear', 'drop', 'thy', 'pipe', 'thy', 'happy', 'pipe', 'sing', 'thy', 'songs', 'of', 'happy', 'cheer', 'so', 'i', 'sung', 'the', 'same', 'again', 'while', 'he', 'wept', 'with', 'joy', 'to', 'hear', 'piper', 'sit', 'thee', 'down', 'and', 'write', 'in', 'a', 'book', 'that', 'all', 'may', 'read', 'so', 'he', 'vanished', 'from', 'my', 'sight', 'and', 'i', 'plucked', 'a', 'hollow', 'reed', 'and', 'i', 'made']

# %%
# Wrap stopword removal from tokens into a function
def remove_stopwords(tokens):
    stop_words = set(stopwords.words('english')) # Set stopwords
    tokens = [token for token in tokens if token not in stop_words] # Remove stopwords
    return tokens

pride_and_prejudice_preprocessed = remove_stopwords(pride_and_prejudice_tokens)
songs_of_innocence_preprocessed = remove_stopwords(songs_of_innocence_tokens)

print("=== Pride and Prejudice - First 100 tokens ===\n", pride_and_prejudice_preprocessed[:100])
print("\n=== Songs of Innocence and of Expectations - First 100 tokens ===\n", songs_of_innocence_preprocessed[:100])
# Out:
# === Pride and Prejudice - First 100 tokens ===
#  ['truth', 'universally', 'acknowledged', 'single', 'man', 'possession', 'good', 'fortune', 'must', 'want', 'wife', 'however', 'little', 'known', 'feelings', 'views', 'man', 'may', 'first', 'entering', 'neighbourhood', 'truth', 'well', 'fixed', 'minds', 'surrounding', 'families', 'considered', 'rightful', 'property', 'one', 'daughters', 'dear', 'mr', 'bennet', 'said', 'lady', 'one', 'day', 'heard', 'netherfield', 'park', 'let', 'last', 'mr', 'bennet', 'replied', 'returned', 'mrs', 'long', 'told', 'mr', 'bennet', 'made', 'answer', 'want', 'know', 'taken', 'cried', 'wife', 'impatiently', 'want', 'tell', 'objection', 'hearing', 'illustration', 'came', 'see', 'place', 'copyright', 'george', 'allen', 'invitation', 'enough', 'dear', 'must', 'know', 'mrs', 'long', 'says', 'netherfield', 'taken', 'young', 'man', 'large', 'fortune', 'north', 'england', 'came', 'monday', 'chaise', 'four', 'see', 'place', 'much', 'delighted', 'agreed', 'mr', 'morris', 'immediately']
#
# === Songs of Innocence and of Expectations - First 100 tokens ===
#  ['piping', 'valleys', 'wild', 'piping', 'songs', 'pleasant', 'glee', 'cloud', 'saw', 'child', 'laughing', 'said', 'pipe', 'song', 'lamb', 'piped', 'merry', 'cheer', 'piper', 'pipe', 'song', 'piped', 'wept', 'hear', 'drop', 'thy', 'pipe', 'thy', 'happy', 'pipe', 'sing', 'thy', 'songs', 'happy', 'cheer', 'sung', 'wept', 'joy', 'hear', 'piper', 'sit', 'thee', 'write', 'book', 'may', 'read', 'vanished', 'sight', 'plucked', 'hollow', 'reed', 'made', 'rural', 'pen', 'stained', 'water', 'clear', 'wrote', 'happy', 'songs', 'every', 'child', 'may', 'joy', 'hear', 'shepherd', 'sweet', 'shepherds', 'sweet', 'lot', 'morn', 'evening', 'strays', 'shall', 'follow', 'sheep', 'day', 'tongue', 'shall', 'filld', 'praise', 'hears', 'lambs', 'innocent', 'call', 'hears', 'ewes', 'tender', 'reply', 'watchful', 'peace', 'know', 'shepherd', 'nigh', 'echoing', 'green', 'sun', 'arise', 'make', 'happy']

# %% [markdown]
# ## 4. Word Frequency Analysis
#
# In this section, we perform a word frequency analysis on both raw and preprocessed texts. We use `Counter` from the collections module to count the occurrences of each word in the texts.
#
# These visualizations help us understand the most dominant words in each author's text and provide insights into stylistic elements characteristic of each author's writing.

# %%
import matplotlib.pyplot as plt
from collections import Counter

# Count the words in both texts with and without stopwords to demonstrate Zipf's law
pride_and_prejudice_raw_word_freq = Counter(pride_and_prejudice_tokens)
pride_and_prejudice_wo_stopwords_word_freq = Counter(pride_and_prejudice_preprocessed)

songs_of_innocence_raw_word_freq = Counter(songs_of_innocence_tokens)
songs_of_innocence_wo_stopwords_word_freq = Counter(songs_of_innocence_preprocessed)

# %%
print("=== Word counts of Pride and Prejudice with stopwords ===")
print(pride_and_prejudice_raw_word_freq)

print("\n=== Word counts of Pride and Prejudice without stopwords ===")
print(pride_and_prejudice_wo_stopwords_word_freq)
# Out:
# === Word counts of Pride and Prejudice with stopwords ===
# Counter({'the': 4352, 'to': 4149, 'of': 3622, 'and': 3542, 'her': 2222, 'i': 2059, 'a': 1942, 'in': 1865, 'was': 1847, 'she': 1707, 'that': 1570, 'not': 1539, 'it': 1523, 'you': 1353, 'he': 1339, 'his': 1274, 'be': 1236, 'as': 1186, 'had': 1173, 'for': 1053, 'with': 1052, 'but': 988, 'is': 857, 'have': 849, 'at': 785, 'mr': 781, 'him': 761, 'on': 722, 'my': 721, 'by': 668, 'all': 624, 'they': 602, 'so': 595, 'elizabeth': 595, 'were': 564, 'which': 538, 'could': 524, 'been': 515, 'from': 494, 'very': 487, 'no': 485, 'what': 479, 'would': 469, 'your': 454, 'me': 446, 'this': 442, 'their': 441, 'them': 435, 'will': 414, 'said': 402, 'such': 388, 'when': 372, 'darcy': 370, 'an': 362, 'there': 349, 'mrs': 346, 'do': 344, 'if': 344, 'are': 342, 'much': 329, 'can': 321, 'am': 320, 'more': 320, 'must': 309, 'bennet': 296, 'or': 294, 'who': 284, 'miss': 284, 'than': 282, 'any': 270, 'did': 270, 'one': 262, 'jane': 262, 'bingley': 259, 'we': 252, 'should': 251, 'know': 238, 'how': 230, 'before': 227, 'herself': 227, 'has': 225, 'never': 224, 'though': 221, 'soon': 216, 'only': 215, 'well': 213, 'now': 211, 'think': 211, 'other': 209, 'some': 206, 'after': 201, 'might': 199, 'time': 196, 'may': 192, 'little': 189, 'own': 188, 'most': 186, 'lady': 182, 'every': 182, 'again': 179, 'sister': 177, 'being': 176, 'nothing': 175, 'then': 171, 'without': 171, 'make': 168, 'good': 167, 'shall': 163, 'dear': 160, 'wickham': 160, 'say': 157, 'illustration': 156, 'collins': 156, 'family': 152, 'see': 150, 'first': 147, 'man': 141, 'into': 141, 'great': 141, 'too': 141, 'two': 137, 'out': 135, 'however': 134, 'ever': 133, 'lydia': 132, 'day': 129, 'young': 129, 'made': 127, 'himself': 125, 'give': 123, 'us': 123, 'hope': 122, 'about': 120, 'always': 119, 'away': 119, 'last': 118, 'many': 118, 'long': 116, 'letter': 116, 'father': 115, 'sisters': 114, 'catherine': 111, 'thought': 111, 'room': 109, 'mother': 108, 'enough': 107, 'way': 106, 'up': 106, 'friend': 104, 'replied': 103, 'house': 103, 'sure': 103, 'its': 103, 'go': 102, 'saw': 101, 'felt': 100, 'wish': 97, 'myself': 95, 'quite': 95, 'lizzy': 94, 'come': 94, 'till': 94, 'manner': 94, 'having': 93, 'came': 92, 'love': 92, 'better': 92, 'indeed': 92, 'pleasure': 92, 'cried': 91, 'oh': 91, 'often': 91, 'over': 90, 'where': 90, 'done': 90, 'feelings': 89, 'really': 89, 'believe': 88, 'longbourn': 88, 'heard': 86, 'whom': 85, 'does': 84, 'subject': 84, 'gardiner': 84, 'happy': 82, 'even': 82, 'take': 80, 'aunt': 80, 'like': 79, 'anything': 79, 'sir': 79, 'whole': 79, 'down': 78, 'less': 78, 'perhaps': 77, 'daughter': 77, 'ladies': 77, 'while': 76, 'morning': 76, 'seen': 76, 'let': 75, 'our': 74, 'still': 74, 'looked': 74, 'yet': 74, 'netherfield': 73, 'certainly': 73, 'next': 72, 'therefore': 72, 'nor': 72, 'something': 72, 'evening': 72, 'happiness': 72, 'just': 71, 'place': 71, 'few': 71, 'added': 71, 'told': 70, 'tell': 70, 'upon': 70, 'hear': 70, 'towards': 70, 'attention': 70, 'here': 69, 'these': 69, 'kitty': 69, 'same': 69, 'both': 69, 'speak': 68, 'present': 68, 'charlotte': 68, 'yes': 68, 'opinion': 67, 'went': 67, 'town': 66, 'found': 66, 'seemed': 66, 'home': 66, 'marriage': 66, 'colonel': 66, 'lucas': 65, 'least': 65, 'left': 65, 'world': 65, 'answer': 64, 'half': 64, 'character': 64, 'moment': 64, 'together': 64, 'each': 64, 'kind': 63, 'either': 62, 'between': 62, 'leave': 62, 'immediately': 61, 'friends': 61, 'acquaintance': 61, 'gone': 61, 'conversation': 61, 'off': 61, 'passed': 61, 'brother': 61, 'received': 61, 'because': 61, 'chapter': 60, 'everything': 60, 'uncle': 60, 'married': 59, 'since': 59, 'find': 59, 'began': 59, 'whose': 59, 'once': 59, 'part': 59, 'seeing': 59, 'almost': 59, 'far': 59, 'coming': 59, 'those': 58, 'affection': 58, 'three': 58, 'daughters': 57, 'party': 57, 'woman': 57, 'knew': 57, 'another': 57, 'going': 57, 'means': 57, 'meryton': 57, 'known': 56, 'mind': 56, 'life': 56, 'given': 56, 'look': 56, 'possible': 56, 'others': 55, 'london': 55, 'behaviour':  ...
#
# === Word counts of Pride and Prejudice without stopwords ===
# Counter({'mr': 781, 'elizabeth': 595, 'could': 524, 'would': 469, 'said': 402, 'darcy': 370, 'mrs': 346, 'much': 329, 'must': 309, 'bennet': 296, 'miss': 284, 'one': 262, 'jane': 262, 'bingley': 259, 'know': 238, 'never': 224, 'though': 221, 'soon': 216, 'well': 213, 'think': 211, 'might': 199, 'time': 196, 'may': 192, 'little': 189, 'lady': 182, 'every': 182, 'sister': 177, 'nothing': 175, 'without': 171, 'make': 168, 'good': 167, 'shall': 163, 'dear': 160, 'wickham': 160, 'say': 157, 'illustration': 156, 'collins': 156, 'family': 152, 'see': 150, 'first': 147, 'man': 141, 'great': 141, 'two': 137, 'however': 134, 'ever': 133, 'lydia': 132, 'day': 129, 'young': 129, 'made': 127, 'give': 123, 'us': 123, 'hope': 122, 'always': 119, 'away': 119, 'last': 118, 'many': 118, 'long': 116, 'letter': 116, 'father': 115, 'sisters': 114, 'catherine': 111, 'thought': 111, 'room': 109, 'mother': 108, 'enough': 107, 'way': 106, 'friend': 104, 'replied': 103, 'house': 103, 'sure': 103, 'go': 102, 'saw': 101, 'felt': 100, 'wish': 97, 'quite': 95, 'lizzy': 94, 'come': 94, 'till': 94, 'manner': 94, 'came': 92, 'love': 92, 'better': 92, 'indeed': 92, 'pleasure': 92, 'cried': 91, 'oh': 91, 'often': 91, 'done': 90, 'feelings': 89, 'really': 89, 'believe': 88, 'longbourn': 88, 'heard': 86, 'subject': 84, 'gardiner': 84, 'happy': 82, 'even': 82, 'take': 80, 'aunt': 80, 'like': 79, 'anything': 79, 'sir': 79, 'whole': 79, 'less': 78, 'perhaps': 77, 'daughter': 77, 'ladies': 77, 'morning': 76, 'seen': 76, 'let': 75, 'still': 74, 'looked': 74, 'yet': 74, 'netherfield': 73, 'certainly': 73, 'next': 72, 'therefore': 72, 'something': 72, 'evening': 72, 'happiness': 72, 'place': 71, 'added': 71, 'told': 70, 'tell': 70, 'upon': 70, 'hear': 70, 'towards': 70, 'attention': 70, 'kitty': 69, 'speak': 68, 'present': 68, 'charlotte': 68, 'yes': 68, 'opinion': 67, 'went': 67, 'town': 66, 'found': 66, 'seemed': 66, 'home': 66, 'marriage': 66, 'colonel': 66, 'lucas': 65, 'least': 65, 'left': 65, 'world': 65, 'answer': 64, 'half': 64, 'character': 64, 'moment': 64, 'together': 64, 'kind': 63, 'either': 62, 'leave': 62, 'immediately': 61, 'friends': 61, 'acquaintance': 61, 'gone': 61, 'conversation': 61, 'passed': 61, 'brother': 61, 'received': 61, 'chapter': 60, 'everything': 60, 'uncle': 60, 'married': 59, 'since': 59, 'find': 59, 'began': 59, 'whose': 59, 'part': 59, 'seeing': 59, 'almost': 59, 'far': 59, 'coming': 59, 'affection': 58, 'three': 58, 'daughters': 57, 'party': 57, 'woman': 57, 'knew': 57, 'another': 57, 'going': 57, 'means': 57, 'meryton': 57, 'known': 56, 'mind': 56, 'life': 56, 'given': 56, 'look': 56, 'possible': 56, 'others': 55, 'london': 55, 'behaviour': 55, 'rather': 55, 'gave': 54, 'whether': 54, 'able': 54, 'side': 54, 'bingleys': 53, 'took': 53, 'get': 52, 'continued': 52, 'certain': 52, 'eyes': 52, 'pemberley': 52, 'visit': 51, 'return': 51, 'walk': 51, 'reason': 51, 'general': 49, 'word': 49, 'ill': 49, 'idea': 49, 'person': 49, 'regard': 49, 'rosings': 49, 'settled': 48, 'object': 48, 'suppose': 48, 'perfectly': 48, 'course': 47, 'people': 46, 'hardly': 46, 'want': 45, 'returned': 45, 'girls': 45, 'business': 45, 'heart': 45, 'manners': 45, 'walked': 45, 'point': 45, 'pride': 45, 'scarcely': 45, 'wife': 44, 'ought': 44, 'impossible': 44, 'spoke': 44, 'agreeable': 44, 'darcys': 44, 'short': 44, 'carriage': 44, 'longer': 44, 'george': 43, 'expected': 43, 'turned': 43, 'right': 43, 'civility': 43, 'marry': 43, 'best': 42, 'back': 42, 'honour': 42, 'else': 42, 'read': 42, 'called': 42, 'husband': 42, 'power': 42, 'cousin': 41, 'help': 41, 'assure': 40, 'william': 40, 'hertfordshire': 40, 'asked': 40, 'convinced': 40, 'talking': 40, 'country': 40, 'fortune': 39, 'rest': 39, 'engaged': 39, 'met': 39, 'spirits': 39, 'feel': 39, 'stay': 39, 'write': 39, 'de': 39, 'likely': 38, 'account': 38, 'dare': 38, 'poor': 38, 'mary': 38, 'wished': 38, 'pleased': 38, 'bennets': 38, 'sat': 38, 'entered': 38, 'brought': 38, 'talked': 38, 'near': 38, 'former': 3 ...

# %%
def plot_top_words(word_freq, title, top_n=25):
    # Get top N most common words
    top_words = word_freq.most_common(top_n)
    words, freqs = zip(*top_words)

    # Create a bar plot
    plt.figure(figsize=(12, 6))
    plt.bar(words, freqs, color='skyblue')
    plt.xlabel('Words')
    plt.ylabel('Frequency')
    plt.xticks(rotation=90)  # Rotate word labels for better readability
    plt.title(f'Top {top_n} Most Frequent Words in {title}')
    plt.show()

# Plot for raw text
plot_top_words(pride_and_prejudice_raw_word_freq, 'with stopwords - Pride and Prejudice')
plot_top_words(songs_of_innocence_raw_word_freq, 'with stopwords - Songs of Innocence and of Expectations')

# Plot for preprocessed text
plot_top_words(pride_and_prejudice_wo_stopwords_word_freq, 'without stopwords - Pride and Prejudice')
plot_top_words(songs_of_innocence_wo_stopwords_word_freq, 'without stopwords - Songs of Innocence and of Expectations')

# %% [markdown]
# ## 5. Lexical Diversity and Sentence Complexity Analysis
#
# Authorship attribution can be informed by analyzing various aspects of writing style, including lexical diversity and sentence complexity. Lexical diversity refers to the range of different words used in a text, often measured by the Type-Token Ratio (TTR). Sentence complexity, on the other hand, can be estimated by metrics like average sentence length and punctuation usage (e.g., commas and semicolons).
#
# We calculate these metrics for both "Pride and Prejudice" and "Songs of Innocence and of Experience." This analysis provides a quantitative basis to compare and contrast the writing styles of Jane Austen and William Blake.

# %%
import numpy as np

def calculate_ttr(tokens):
    """ Calculate Type-Token Ratio (TTR) for lexical diversity. """
    types = set(tokens)
    return len(types) / len(tokens)

def calculate_avg_sentence_length(text):
    """ Calculate the average sentence length. """
    sentences = sent_tokenize(text)
    return sum(len(word_tokenize(sentence)) for sentence in sentences) / len(sentences)

def calculate_sentence_complexity(text):
    """ Calculate sentence complexity based on comma and semicolon usage. """
    sentences = sent_tokenize(text)
    punctuation_counts = sum(sentence.count(',') + sentence.count(';') for sentence in sentences)
    return punctuation_counts / len(sentences)

# Calculate metrics
austen_metrics = {
    'avg_sentence_length': calculate_avg_sentence_length(pride_and_prejudice_text),
    'ttr': calculate_ttr(pride_and_prejudice_tokens),
    'complexity': calculate_sentence_complexity(pride_and_prejudice_text)
}

blake_metrics = {
    'avg_sentence_length': calculate_avg_sentence_length(songs_of_innocence_text),
    'ttr': calculate_ttr(songs_of_innocence_tokens),
    'complexity': calculate_sentence_complexity(songs_of_innocence_text)
}

# Display some analysis results
print("=== Type-Token Ratio ===")
print("Pride and Prejudice: ", austen_metrics['ttr'])
print("Songs of Innocence and of Experience: ", blake_metrics['ttr'])
print()
print("=== Average Sentence Length in Words ===")
print("Pride and Prejudice: ", austen_metrics['avg_sentence_length'])
print("Songs of Innocence and of Experience: ", blake_metrics['avg_sentence_length'])
print()
print("=== Sentence Complexity ===")
print("Pride and Prejudice", austen_metrics['complexity'])
print("Songs of Innocence and of Experience", blake_metrics['complexity'])
# Out:
# === Type-Token Ratio ===
# Pride and Prejudice:  0.05501372279945109
# Songs of Innocence and of Experience:  0.23813953488372094
#
# === Average Sentence Length in Words ===
# Pride and Prejudice:  31.18470790378007
# Songs of Innocence and of Experience:  25.8984375
#
# === Sentence Complexity ===
# Pride and Prejudice 2.397121993127148
# Songs of Innocence and of Experience 2.7421875

# %% [markdown]
# ## 6. Bag of Words Model for Authorship Attribution
#
# The Bag of Words (BoW) model is a simple yet effective approach in natural language processing. It represents text data as the frequency of words without considering their order or context. In this section, we build a BoW model for both texts, focusing on the most frequent words used by each author.
#
# We then define a function `authorship_attribution_bow` to predict the authorship of a given text snippet based on the frequency of characteristic words of each author. This heuristic approach compares the occurrences of an author's characteristic words in the snippet and attributes authorship to the one with the higher word frequency score.

# %%
def get_top_words(freq_dist, top_n=100):
    """Get top N words from a frequency distribution."""
    return [word for word, freq in freq_dist.most_common(top_n)]

# Get top N words from each author
top_n = 250
austen_characteristic_words = get_top_words(pride_and_prejudice_wo_stopwords_word_freq, top_n)
blake_characteristic_words = get_top_words(songs_of_innocence_wo_stopwords_word_freq, top_n)

def authorship_attribution_bow(text, austen_words, blake_words):
    text_tokens = word_tokenize(text.lower())
    text_word_freq = Counter(text_tokens)

    austen_score = sum(text_word_freq[word] for word in austen_words if word in text_word_freq)
    blake_score = sum(text_word_freq[word] for word in blake_words if word in text_word_freq)

    if austen_score > blake_score:
        return "Jane Austen"
    elif blake_score > austen_score:
        return "William Blake"
    else:
        return "Uncertain"

# %%
# Chapter 1 of Jane Austen's "Sense and Sensibility"
text = "\
The family of Dashwood had long been settled in Sussex. Their estate\
was large, and their residence was at Norland Park, in the centre of\
their property, where, for many generations, they had lived in so\
respectable a manner as to engage the general good opinion of their\
surrounding acquaintance. The late owner of this estate was a single\
man, who lived to a very advanced age, and who for many years of his\
life, had a constant companion and housekeeper in his sister. But her\
death, which happened ten years before his own, produced a great\
alteration in his home; for to supply her loss, he invited and received\
into his house the family of his nephew Mr. Henry Dashwood, the legal\
inheritor of the Norland estate, and the person to whom he intended to\
bequeath it. In the society of his nephew and niece, and their\
children, the old Gentleman’s days were comfortably spent. His\
attachment to them all increased. The constant attention of Mr. and\
Mrs. Henry Dashwood to his wishes, which proceeded not merely from\
interest, but from goodness of heart, gave him every degree of solid\
comfort which his age could receive; and the cheerfulness of the\
children added a relish to his existence."

author_prediction = authorship_attribution_bow(text, austen_characteristic_words, blake_characteristic_words)
print(f"The text is likely written by {author_prediction}.")
# Out:
# The text is likely written by Jane Austen.

# %%
# Chapter 1 of Jane Austen's "Persuasion"
text ="\
Sir Walter Elliot, of Kellynch Hall, in Somersetshire, was a man who,\
for his own amusement, never took up any book but the Baronetage; there\
he found occupation for an idle hour, and consolation in a distressed\
one; there his faculties were roused into admiration and respect, by\
contemplating the limited remnant of the earliest patents; there any\
unwelcome sensations, arising from domestic affairs changed naturally\
into pity and contempt as he turned over the almost endless creations\
of the last century; and there, if every other leaf were powerless, he\
could read his own history with an interest which never failed. This\
was the page at which the favourite volume always opened."

author_prediction = authorship_attribution_bow(text, austen_characteristic_words, blake_characteristic_words)
print(f"The text is likely written by {author_prediction}.")
# Out:
# The text is likely written by Jane Austen.

# %%
# Poem from "The Marriage of Heaven and Hell" by William Blake
text = "\
Rintrah roars and shakes his fires in the burden'd air,\
Hungry clouds swag on the deep.\
Once meek, and in a perilous path\
The just man kept his course along\
The Vale of Death.\
Roses are planted where thorns grow,\
And on the barren heath\
Sing the honey bees."

author_prediction = authorship_attribution_bow(text, austen_characteristic_words, blake_characteristic_words)
print(f"The text is likely written by {author_prediction}.")
# Out:
# The text is likely written by Jane Austen.

# %%
# "Poems of William Blake"
text = "Youth of delight! come hither\
And see the opening morn,\
Image of Truth new-born.\
Doubt is fled, and clouds of reason,\
Dark disputes and artful teazing.\
Folly is an endless maze;\
Tangled roots perplex her ways;\
How many have fallen there!\
They stumble all night over bones of the dead;\
And feel—they know not what but care;\
And wish to lead others, when they should be led."

author_prediction = authorship_attribution_bow(text, austen_characteristic_words, blake_characteristic_words)
print(f"The text is likely written by {author_prediction}.")
# Out:
# The text is likely written by William Blake.

# %% [markdown]
# ## 7. Bigrams Analysis for Deeper Linguistic Insights
#
# Bigrams, or pairs of consecutive words, offer deeper insights into an author's writing style than single words. This section explores bigram usage in our texts. We generate and analyze bigrams for both "Pride and Prejudice" and "Songs of Innocence and of Experience" using NLTK's bigrams function.
#
# We then perform a frequency analysis of these bigrams, identifying the most common bigrams used by each author. A function `authorship_attribution_bigrams` is defined to predict authorship based on the presence of these characteristic bigrams in a text snippet. This approach provides another layer of stylistic analysis, complementing our previous Bag of Words model.

# %%
from nltk import bigrams

def generate_bigrams(text):
    """Generate bigrams from a list of tokens."""
    tokens = word_tokenize(text.lower())
    return list(bigrams(tokens))

# %%
austen_bigrams = generate_bigrams(pride_and_prejudice_text)
blake_bigrams = generate_bigrams(songs_of_innocence_text)

print("=== Pride and Prejudice bigrams ===")
print(austen_bigrams[:50])
print("\n=== Songs of Innocence and Experience bigrams ===")
print(blake_bigrams[:50])
# Out:
# === Pride and Prejudice bigrams ===
# [('it', 'is'), ('is', 'a'), ('a', 'truth'), ('truth', 'universally'), ('universally', 'acknowledged'), ('acknowledged', ','), (',', 'that'), ('that', 'a'), ('a', 'single'), ('single', 'man'), ('man', 'in'), ('in', 'possession'), ('possession', 'of'), ('of', 'a'), ('a', 'good'), ('good', 'fortune'), ('fortune', 'must'), ('must', 'be'), ('be', 'in'), ('in', 'want'), ('want', 'of'), ('of', 'a'), ('a', 'wife'), ('wife', '.'), ('.', 'however'), ('however', 'little'), ('little', 'known'), ('known', 'the'), ('the', 'feelings'), ('feelings', 'or'), ('or', 'views'), ('views', 'of'), ('of', 'such'), ('such', 'a'), ('a', 'man'), ('man', 'may'), ('may', 'be'), ('be', 'on'), ('on', 'his'), ('his', 'first'), ('first', 'entering'), ('entering', 'a'), ('a', 'neighbourhood'), ('neighbourhood', ','), (',', 'this'), ('this', 'truth'), ('truth', 'is'), ('is', 'so'), ('so', 'well'), ('well', 'fixed')]
#
# === Songs of Innocence and Experience bigrams ===
# [('piping', 'down'), ('down', 'the'), ('the', 'valleys'), ('valleys', 'wild'), ('wild', ','), (',', 'piping'), ('piping', 'songs'), ('songs', 'of'), ('of', 'pleasant'), ('pleasant', 'glee'), ('glee', ','), (',', 'on'), ('on', 'a'), ('a', 'cloud'), ('cloud', 'i'), ('i', 'saw'), ('saw', 'a'), ('a', 'child'), ('child', ','), (',', 'and'), ('and', 'he'), ('he', 'laughing'), ('laughing', 'said'), ('said', 'to'), ('to', 'me'), ('me', ':'), (':', '‘'), ('‘', 'pipe'), ('pipe', 'a'), ('a', 'song'), ('song', 'about'), ('about', 'a'), ('a', 'lamb'), ('lamb', '!'), ('!', '’'), ('’', 'so'), ('so', 'i'), ('i', 'piped'), ('piped', 'with'), ('with', 'merry'), ('merry', 'cheer'), ('cheer', '.'), ('.', '‘'), ('‘', 'piper'), ('piper', ','), (',', 'pipe'), ('pipe', 'that'), ('that', 'song'), ('song', 'again.'), ('again.', '’')]

# %%
def get_most_common_bigrams(text, top_n=250):
    text_bigrams = generate_bigrams(text)
    bigram_freq = Counter(text_bigrams)
    return [bigram for bigram, _ in bigram_freq.most_common(top_n)]

# %%
austen_common_bigrams = get_most_common_bigrams(pride_and_prejudice_text)
blake_common_bigrams = get_most_common_bigrams(songs_of_innocence_text)

print("=== Most common Pride and Prejudice bigrams ===")
print(austen_common_bigrams)
print("\n=== Most common Songs of Innocence and Experience bigrams ===")
print(blake_common_bigrams)
# Out:
# === Most common Pride and Prejudice bigrams ===
# [(',', 'and'), (';', 'and'), ('”', '“'), ('’', 's'), ('of', 'the'), ('to', 'be'), (',', '”'), (',', 'i'), ('in', 'the'), ('.', '“'), ('.', 'i'), (',', 'that'), (',', '“'), (';', 'but'), ('i', 'am'), (',', 'she'), ('“', 'i'), ('of', 'her'), ('mr.', 'darcy'), ('.', 'she'), ('?', '”'), ('to', 'the'), ('it', 'was'), ('”', 'said'), ('of', 'his'), ('.', 'the'), (',', 'as'), ('.', 'but'), (',', 'to'), ('she', 'was'), ('she', 'had'), ('had', 'been'), (',', 'in'), (',', 'but'), ('it', 'is'), ('i', 'have'), ('.', 'he'), ('that', 'he'), ('to', 'her'), ('could', 'not'), ('.', 'it'), (',', 'he'), ('he', 'had'), ('for', 'the'), ('and', ','), ('and', 'the'), ('he', 'was'), ('[', 'illustration'), ('on', 'the'), ('elizabeth', ','), ('mrs.', 'bennet'), (',', '--'), (',', 'with'), ('mr.', 'collins'), ('such', 'a'), (',', 'who'), (',', 'the'), (',', 'which'), ('in', 'a'), ('have', 'been'), ('did', 'not'), ('they', 'were'), ('she', 'could'), ('that', 'she'), (',', 'was'), (',', 'for'), (',', 'however'), ('was', 'not'), (',', 'though'), ('--', '“'), ('my', 'dear'), ('and', 'i'), (',', 'you'), ('with', 'the'), ('do', 'not'), ('her', ','), (',', 'or'), (',', 'when'), ('it', ','), ('lady', 'catherine'), ('.', '['), ('not', 'be'), ('of', 'a'), ('mr.', 'bingley'), ('however', ','), ('him', ','), ('can', 'not'), ('and', 'she'), ('by', 'the'), ('it', '.'), ('.', 'elizabeth'), ('all', 'the'), ('darcy', ','), ('as', 'to'), (',', 'my'), ('i', 'can'), ('.', 'mr.'), ('that', 'i'), (',', 'if'), ('.', 'they'), (',', 'it'), ('.', 'you'), ('but', 'i'), ('at', 'the'), ('bennet', ','), ('you', 'are'), ('from', 'the'), ('“', 'and'), ('as', 'she'), ('in', 'her'), ('would', 'be'), ('“', 'you'), ('her', '.'), ('i', 'do'), ('and', 'her'), (',', 'by'), ('her', 'sister'), ('with', 'a'), ('mr.', 'bennet'), ('to', 'his'), ('of', 'their'), ('you', ','), ('miss', 'bingley'), ('there', 'was'), ('will', 'be'), (';', 'for'), ('illustration', ']'), (',', 'of'), ('”', 'elizabeth'), ('with', 'her'), ('would', 'have'), ('“', 'but'), ('!', '”'), ('to', 'make'), ('was', 'a'), ('of', 'it'), ('i', 'shall'), ('must', 'be'), ('jane', ','), ('for', 'her'), ('a', 'very'), ('to', 'have'), ('of', 'my'), ('you', 'have'), ('me', ','), ('him', 'to'), ('to', 'see'), ('you', 'will'), ('is', 'not'), ('is', 'a'), ('he', 'is'), (':', '“'), ('her', 'mother'), ('”', 'she'), ('.', 'mrs.'), ('in', 'his'), ('had', 'not'), (';', '“'), ('would', 'not'), ('will', 'not'), ('that', 'the'), ('the', 'whole'), ('”', 'cried'), ('oh', ','), ('them', ','), ('i', 'should'), (',', 'had'), ('illustration', ':'), ('.', 'her'), ('it', 'would'), ('him', '.'), ('that', 'it'), ('the', 'room'), ('there', 'is'), ('the', 'same'), (',', 'mr.'), ('.', 'his'), ('one', 'of'), ('bingley', ','), ('but', ','), ('if', 'you'), ('of', 'your'), ('of', 'mr.'), ('i', 'was'), ('miss', 'bennet'), ('mr.', 'wickham'), ('she', 'is'), ('“', 'oh'), ('that', 'you'), ('to', 'say'), ('they', 'had'), ('so', 'much'), ('not', 'to'), ('of', 'all'), ('at', 'all'), ('.', 'in'), ('elizabeth', 'was'), ('you', 'must'), ('as', 'he'), ('“', 'it'), ('am', 'sure'), ('the', 'world'), ('and', 'elizabeth'), (',', 'after'), ('her', 'own'), (']', 'chapter'), ('as', 'they'), ('should', 'be'), ('”', 'replied'), ('as', 'soon'), ('more', 'than'), ('“', 'that'), ('if', 'he'), ('of', 'what'), ('.', 'when'), (',', 'they'), ('was', 'to'), ('as', 'i'), ('the', 'first'), ('said', ','), (',', 'on'), ('the', 'other'), ('soon', 'as'), ('i', 'hope'), ('her', 'to'), ('and', 'his'), ('indeed', ','), ('.', 'my'), ('mrs.', 'gardiner'), ('a', 'few'), ('lizzy', ','), ('she', 'would'), ('and', 'then'), ('but', 'it'), ('well', ','), ('for', 'a'), ('”', '['), ('the', 'house'), ('into', 'the'), ('i', 'will'), ('and', 'that'), (',', 'therefore'), ('.', 'and'), ('to', 'think'), ('them', '.'), ('a', 'little'), ('i', 'had'), (',', 'at'), (',', 'indeed'), ('could', 'be')]
#
# === Most common Songs of Innocence and Experience bigrams ===
# [(',', 'and'), ('’', 's'), ('in', 'the'), ('.', 'the'), (',', 'the'), ('and', 'the'), ('.', '‘'), ('’', 'er'), ('of', 'the'), (',', 'in'), (';', 'and'), ('o', '’'), ('sleep', ','), ('and', 'i'), ('on', 'the'), ('the', 'little'), ('.', 'and'), ('the', 'human'), (',', 'who'), (',', 'i'), (',', 'nor'), ('!', '’'), ('in', 'a'), (',', 'but'), ('night', ','), ('the', 'night'), ('when', 'the'), (',', 'that'), ('to', 'the'), ('lamb', ','), (',', 'when'), (',', 'my'), (',', 'they'), ('love', ','), ('and', 'he'), ('day', ','), ('the', 'sun'), ('thee', '?'), ('delight', ','), ('me', ','), ('father', ','), (',', 'or'), ('from', 'the'), ('all', 'the'), (';', 'the'), (',', 'with'), ('little', 'lamb'), (',', 'he'), ('my', 'mother'), ('i', 'am'), ('joy', ','), ('little', 'boy'), (',', 'to'), ('!', 'sweet'), ('weep', '.'), (',', 'on'), (':', '‘'), ('’', 'so'), (',', 'while'), (',', 'for'), ('no', 'more'), ('who', 'made'), ('a', 'little'), ('like', 'a'), ('i', 'was'), ('weep', '!'), ('.', 'then'), (',', 'all'), (',', 'where'), ('deep', ','), ('with', 'the'), ('an', 'infant'), ('pity', ','), ('in', 'every'), ('while', 'the'), ('and', 'not'), ('can', 'it'), ('where', 'the'), (';', 'but'), ('child', ','), ('so', 'i'), ('.', 'for'), ('peace', ','), ('care', ','), (',', '‘'), ('till', 'the'), (',', 'like'), ('thee', ','), ('er', 'the'), ('i', '’'), ('thee', '!'), ('and', ','), ('away', ','), ('and', 'we'), ('!', 'never'), (';', 'then'), ('’', 'd'), ('’', 'the'), ('the', 'green'), ('smiles', ','), ('mercy', ','), ('human', 'form'), (',', 'till'), ('and', 'weep'), (',', '—'), ('can', 'i'), ('?', 'can'), ('it', 'be'), ('hear', 'the'), ('?', 'and'), ('?', 'what'), ('a', 'lamb'), ('the', 'morn'), ('he', 'is'), ('sun', 'does'), ('among', 'the'), ('play', ','), (',', 'no'), ('in', 'their'), ('made', 'thee'), ('voice', ','), ('’', 'll'), ('by', 'his'), ('an', 'angel'), ('tree', ','), ('‘', 'and'), ('of', 'love'), ('and', 'care'), ('!', 'weep'), (',', 'if'), ('the', 'morning'), ('there', ','), ('the', 'child'), ('the', 'voice'), ('voice', 'of'), ('infant', '’'), ('.', 'sweet'), (',', 'sleep'), ('in', 'thy'), ('i', 'can'), ('smiles', 'on'), (',', 'pity'), (',', 'peace'), ('and', 'love'), (',', 'is'), ('care', '.'), ('a', 'human'), ('snow', ','), ('day', 'and'), ('and', 'night'), ('merrily', ','), (',', 'merrily'), ('little', 'girl'), ('‘', 'i'), ('?', '‘'), ('sweet', 'joy'), ('to', 'see'), ('another', '’'), ('i', 'see'), ('never', 'can'), ('be', '!'), ('of', 'woe'), ('the', 'holy'), ('?', 'the'), ('filled', 'with'), ('.', 'in'), ('how', 'can'), (';', 'in'), ('in', 'my'), ('the', 'church'), ('and', 'sing'), ('of', 'my'), ('in', 'vain'), ('tiger', ','), (',', 'what'), ('what', 'the'), ('morn', ','), ('songs', 'of'), ('a', 'cloud'), ('i', 'saw'), ('a', 'child'), ('to', 'me'), ('me', ':'), ('a', 'song'), (':', 'he'), ('to', 'hear'), ('hear', '.'), ('joy', 'to'), ('so', 'he'), ('the', 'evening'), ('and', 'his'), ('shall', 'be'), ('the', 'echoing'), ('arise', ','), ('to', 'welcome'), ('the', 'birds'), (';', 'while'), ('seen', 'on'), ('green', '.'), ('hair', ','), ('.', 'they'), ('little', 'ones'), ('round', 'the'), ('nest', ','), ('?', 'does'), ('gave', 'thee'), ('by', 'the'), ('of', 'delight'), ('bright', ';'), ('such', 'a'), (';', 'little'), ('.', 'he'), ('.', 'i'), ('i', 'a'), (',', 'we'), ('.', 'little'), ('!', 'the'), ('black', ','), ('but', 'i'), (',', 'as'), ('the', 'heat'), ('began', 'to'), ('live', ','), ('light', ','), ('for', ','), ('!', 'under'), ('a', 'happy'), (',', 'near'), ('bosom', '.'), (',', 'pretty'), ('the', 'chimney-sweeper'), ('my', 'father'), ('‘', 'weep'), ('his', 'head'), ('head', ','), ('and', 'so'), ('and', 'by'), ('all', 'their'), (':', 'and'), ('boy', ','), ('dark', ','), ('boy', 'lost'), (',', 'father'), ('lost', 'in'), ('to', 'his'), ('dale', ','), ('song', 'when'), ('laugh', 'with'), ('of', 'joy'), (';', 'when')]

# %%
def authorship_attribution_bigrams(text, austen_bigrams, blake_bigrams):
    """ Compare the bigrams of a new text against Austen's and Blake's bigram counts. """
    tokens = word_tokenize(text.lower())
    text_bigrams = Counter(bigrams(tokens))

    # Count how many top bigrams for each author are present in the text
    austen_bigram_count = sum(text_bigrams[bigram] for bigram in austen_bigrams)
    blake_bigram_count = sum(text_bigrams[bigram] for bigram in blake_bigrams)



    # Heuristic decision based on metrics and bigrams
    if austen_bigram_count > blake_bigram_count:
        return "Jane Austen"
    elif blake_bigram_count > austen_bigram_count:
        return "William Blake"
    else:
        return "Uncertain"

# %%
# Chapter 1 of Jane Austen's "Sense and Sensibility"
text = "\
The family of Dashwood had long been settled in Sussex. Their estate\
was large, and their residence was at Norland Park, in the centre of\
their property, where, for many generations, they had lived in so\
respectable a manner as to engage the general good opinion of their\
surrounding acquaintance. The late owner of this estate was a single\
man, who lived to a very advanced age, and who for many years of his\
life, had a constant companion and housekeeper in his sister. But her\
death, which happened ten years before his own, produced a great\
alteration in his home; for to supply her loss, he invited and received\
into his house the family of his nephew Mr. Henry Dashwood, the legal\
inheritor of the Norland estate, and the person to whom he intended to\
bequeath it. In the society of his nephew and niece, and their\
children, the old Gentleman’s days were comfortably spent. His\
attachment to them all increased. The constant attention of Mr. and\
Mrs. Henry Dashwood to his wishes, which proceeded not merely from\
interest, but from goodness of heart, gave him every degree of solid\
comfort which his age could receive; and the cheerfulness of the\
children added a relish to his existence."

author_prediction = authorship_attribution_bigrams(text, austen_common_bigrams, blake_common_bigrams)
print(f"The text is likely written by {author_prediction}.")
# Out:
# The text is likely written by Jane Austen.

# %%
# Chapter 1 of Jane Austen's "Persuasion"
text ="\
Sir Walter Elliot, of Kellynch Hall, in Somersetshire, was a man who,\
for his own amusement, never took up any book but the Baronetage; there\
he found occupation for an idle hour, and consolation in a distressed\
one; there his faculties were roused into admiration and respect, by\
contemplating the limited remnant of the earliest patents; there any\
unwelcome sensations, arising from domestic affairs changed naturally\
into pity and contempt as he turned over the almost endless creations\
of the last century; and there, if every other leaf were powerless, he\
could read his own history with an interest which never failed. This\
was the page at which the favourite volume always opened."

author_prediction = authorship_attribution_bigrams(text, austen_common_bigrams, blake_common_bigrams)
print(f"The text is likely written by {author_prediction}.")
# Out:
# The text is likely written by Jane Austen.

# %%
# "From the Marriage of Heaven and Hell" by William Blake
text = "\
Rintrah roars and shakes his fires in the burden'd air,\
Hungry clouds swag on the deep.\
Once meek, and in a perilous path\
The just man kept his course along\
The Vale of Death.\
Roses are planted where thorns grow,\
And on the barren heath\
Sing the honey bees."

author_prediction = authorship_attribution_bigrams(text, austen_common_bigrams, blake_common_bigrams)
print(f"The text is likely written by {author_prediction}.")
# Out:
# The text is likely written by Uncertain.

# %%
# "Poems of William Blake"
text = "Youth of delight! come hither\
And see the opening morn,\
Image of Truth new-born.\
Doubt is fled, and clouds of reason,\
Dark disputes and artful teazing.\
Folly is an endless maze;\
Tangled roots perplex her ways;\
How many have fallen there!\
They stumble all night over bones of the dead;\
And feel—they know not what but care;\
And wish to lead others, when they should be led."

author_prediction = authorship_attribution_bigrams(text, austen_common_bigrams, blake_common_bigrams)
print(f"The text is likely written by {author_prediction}.")
# Out:
# The text is likely written by William Blake.
